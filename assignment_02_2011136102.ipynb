# %% [markdown]
# Script Programming Assignment - 02
# ======
# ###　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　한연희 교수님 / 1분반
# ###　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　컴퓨터공학부 / 2011136102 / 장준영
# ###　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　제출일 : 2014. 9. 25. (목)

# %% [markdown]
# -----
# ###**1. 다음 6 개의 Expression에 대해 Evaluation 결과 값을 출력하고, 해당 결과가 나온 이유에 대해 설명하시오.**
# - 1 and 2 and 3 and 4
# - 1 or 2 or 3 or 4
# - 1 and 2 or 3 and 4
# - (1 and 2) or (3 and 4)
# - 1 or 2 and 3 or 4
# - (1 or 2) and (3 or 4)

# %%
print 1 and 2 and 3 and 4
print 1 or 2 or 3 or 4
print 1 and 2 or 3 and 4
print (1 and 2) or (3 and 4)
print 1 or 2 and 3 or 4
print (1 or 2) and (3 or 4)
# Out:
# 4
# 1
# 2
# 2
# 1
# 3

# %% [markdown]
# ###**설명**
#
# 1) 논리 연산자의 연산 방식
# - x and y : x가 참이면 y, 아니면 x
# - x or y  : x가 참이면 x, 아니면 y
#
# 2) 논리 연산자의 우선 순위
# - and 연산이 or 연산보다 우선순위가 높다.
#
# 3) 연산의 방향
# - 연산은 왼쪽에서 오른쪽으로 이루어진다.
#
# (1) 1 and 2 and 3 and 4
# == (((1 and 2) and 3) and 4)
# == ((2 and 3) and 4)
# == (3 and 4)
# == 4
#
# (2) 1 or 2 or 3 or 4
# == (((1 or 2) or 3) or 4)
# == ((1 or 3) or 4)
# == (1 or 4)
# == 1
#
# (3) 1 and 2 or 3 and 4
# == (1 and 2) or (3 and 4)
# == 2 or 4
# == 2
#
# (4) (1 and 2) or (3 and 4)
# == 2 or 4
# == 2
#
# (5) 1 or 2 and 3 or 4
# == ((1 or (2 and 3)) or 4)
# == ((1 or 3) or 4)
# == 1 or 4
# == 1
#
# (6) (1 or 2) and (3 or 4)
# == 1 and 3
# == 3

# %% [markdown]
# -----
# ###**2. 7/5, -7/5, -(7/5)의 결과를 확인하고 각각의 결과가 왜 그렇게 나오는 지 설명하시오.**
# [참고] 몫은 항상 음의 무한대 방향으로 round up (반올림) 된다는 점을 기억해야 함

# %%
print 7/5
print -7/5
print -(7/5)
# Out:
# 1
# -2
# -1

# %% [markdown]
# ###**설명**
#
# (1) 7/5
# == (1.4에서 음의 무한대 방향으로 반올림한 정수)
# == 1
#
# (2) -7/5
# == (-1.4에서 음의 무한대 방향으로 반올림한 정수)
# == -2
#
# (3) -(7/5)
# == -( (1.4에서 음의 무한대 방향으로 반올림한 정수) )
# == -(1)
# == -1

# %% [markdown]
# -----
# ###**3. 키보드로 정수값을 입력 받고 그 값이 양수인지 음수인지를 비트 연산자를 이용하여 판단하는 프로그램을 작성하시오.**
# [참고] 가장 왼쪽에 있는 비트가 0이면 양수이며, 1이면 음수이다.

# %%
input = int(raw_input("Enter a integer number : "))
if (input):
    if ((input >> 31) & 1):
        print "음수 입니다."
    else:
        print "양수 입니다."
else:
    print "0 입니다."
# Out:
# Enter a integer number : -30
# 음수 입니다.

# %% [markdown]
# ###**설명**
#
# int형은 32비트 자료형이다. 32번째 비트의 수는 MSB(Most Significant Bit)로써, 0일 때 양수, 1일 때 음수를 나타낸다.
# int형 값에서 31번 오른쪽 쉬프트 연산을 한 다음, 1과 비트 단위 AND 연산을 하면 MSB의 값을 알 수 있다.
# 그 값을 바탕으로 음수와 양수를 판별한다.

# %% [markdown]
# -----
# ###**4. 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '합집합'을 반환하는 함수 list_union(lista, listb)를 작성하시오.**
# - 인자로 전달하는 리스트 2 개에는 정수값만 들어간다고 가정하자.
# - 함수 내에서 새로운 리스트를 만들어 그 리스트 내에 인자로 받은 두 리스트의 모든 원소를 넣어 반환한다.
# - 반환하는 리스트에는 절대로 중복된 원소가 들어 있으면 안된다 (집합의 조건).
# - 반환하는 리스트는 정렬이 되어 있어야 한다.
# - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - list_union([1, 2, 3], [1, 2, 4])
#         - [1, 2, 3, 4]
#     - list_union([-10, -5, 0, -1], [100, 9, 0, 9])
#         - [-10, -5, -1, 0, 9, 100]
#     - list_union([0, 1, 2], [0, 1, 2])
#         - [0, 1, 2]
# - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.
# - [참고] 임의의 정수값 (x)이 리스트 (l) 내에 존재하는지 판단하는 방법은 x in l 이다.

# %%
def list_union(a, b):
    c = a
    for k in b:
        if k not in c :
            c.append(k)        
    c.sort()
    return c

a = [-10, -5, 0, -1]
b = [100, 9, 0, 9]
c = list_union(a, b)
print c
# Out:
# [-10, -5, -1, 0, 9, 100]

# %% [markdown]
# ###**설명**
# 1) c가 a 리스트를 가리키게 한다.
# 2) c에 b의 원소들을 넣는다. 이 때, 이미 c에 들어있는 원소는 넣지 않는다.
# 3) c를 정렬한다.
# 4) c를 리턴한다.

# %% [markdown]
# -----
# ###**5. 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.**
# - 인자로 전달하는 문자열은 경로만 들어간다고 가정한다.
# - 각 디렉토리와 파일을 구분하는 문자는 '/'로 가정한다.
# - 반환하는 리스트의 첫번째 원소는 디렉토리이고 두번째 원소는 파일명이다.
# - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - div_path('/usr/local/bin/python')
#         - ['/usr/local/bin', 'python']
#     - div_path('/home/chulsoo/test.txt')
#         - ['/home/chulsoo', 'test.txt']

# %%
def div_path(s):
    s_range = range(len(s))
    for k in s_range:
        if s[k] == '/':
            index = k
    path = s[:index]
    filename = s[index+1:]
    return path, filename;
a, b = div_path('/home/chulsoo/test.txt')
print a
print b
# Out:
# /home/chulsoo
# test.txt

# %% [markdown]
# ###**설명**
# 문자열에서 가장 나중에 나오는 '/'를 찾은 다음, 그 문자를 기준으로 앞은 path, 뒤는 filename으로 구분한다.

# %% [markdown]
# -----
# ###**6. 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트만을 출력하고, 2) 그 순수 텍스트 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.**
#
# - HTML 태그는 다음 조건을 가지는 것이다.
#     - < 로 시작하여 >로 끝나거나 />로 끝난다.
#     - </ 로 시작하여 > 로 끝난다.
# - HTML 문서 내에 존재하는 CSS 삭제시 참고할 사항
#     - `<style>` 혹은 `<STYLE>`로 시작한다.
#     - `</style>` 혹은 `</STYLE>`로 끝난다.
#     - `<style>` (혹은 `<STYLE>`)과 `</style>` (혹은 `</STYLE>`) 내에 존재하는 CSS 코드는 모두 삭제한다.
#     - HTML 문서 내에 존재하는 Javascript 삭제시 참고할 사항
#     - `<script>` 혹은 `<SCRIPT>`로 시작한다.
#     - `</script>` 혹은 `</SCRIPT>`로 끝난다.
#     - `<script>` (혹은 `<SCRIPT>`)과 `</script>` (혹은 `</SCRIPT>`) 내에 존재하는 Javascript 코드는 모두 삭제한다.
# - 즉, CSS 코드와 Javascript 코드는 단어의 총수를 카운트 할 때 고려하지 않는다.
# - 한편, 다음은 URL로 지정된 웹페이지를 특정 문자열로 가져오는 코드이다.

# %%
import urllib
s = urllib.urlopen('http://cse.kut.ac.kr/').read()
temp_result = []
open_cnt = 0
close_cnt = 0
is_in_par = False;
is_style_script = False;
range_s = range(len(s));
for k in range_s:
	if is_in_par:
		if s[k] == '>':
			close_cnt = close_cnt + 1
			if s.startswith('/style', k-6) or s.startswith('/STYLE', k-6) or\
			s.startswith('/script', k-7) or s.startswith('/SCRIPT', k-7) :
				is_style_script = False;
			if open_cnt == close_cnt:
				is_in_par = False
			continue
		elif s[k] == '<':
			open_cnt = open_cnt + 1
		else:
			continue
	else: # not in par
		if s[k] == '<':
			temp_result.append(' ')
			open_cnt = open_cnt + 1
			is_in_par = True
			if s.startswith('style', k+1) or s.startswith('STYLE', k+1) or\
			s.startswith('script', k+1) or s.startswith('SCRIPT', k+1) :
				is_style_script = True;
			continue
		else:
			if is_style_script:
				continue
			else:
				temp_result.append(s[k])
result = ''.join(temp_result)
print result
print
print '총 단어의 수 = ' + str(len(result.split()))
# Out:
#
#
#
#
#
#
#
#
#  컴퓨터공학부 홈페이지
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																									  컴퓨터공학부
# 																	 : 					  교육목표
# 																	 : 					  찾아오시는길
# 																	 : 					  졸업작품
# 																	 : 					  공학설계
# 																	 : 					  취업조사2014
# 																	 : 					  취업조사2013
#
#
# 																									  교수진
# 																	 : 					  학생회
#
#
# 																									  졸업이수요건
# 																	 : 					  컴퓨터S/W
# 																	 : 					  컴퓨터H/W
# 																	 : 					  컴퓨터스마트IT
# 																	 : 					  컴퓨터시스템응용
# 																	 : 					  장학제도
#
#
# 																									  모집요강
# 																	 : 					  입시Q&A
#
#
# 																									  공지사항
# 																	 : 					  자유게시판
# 																	 : 					  익명게시판
# 																	 : 					  취업게시판
# 																	 : 					  동문게시판
# 																	 : 					  사진게시판
# 																	 : 					  학부사진겔러리
# 																	 : 					  고장신고게시판
#
#
# 																									  강의자료실
# 																	 : 					  일반자료실
# 																	 : 					  서식및양식자료실
#
#
# 																									  대학원소개
# 																	 : 					  연구실소개
# 																	 : 					  대학원게시판
#
#
# 																									  공학인증안내
# 																	 : 					  공학인증게시판
# 																	 :
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			   C++   2014/03/27
# 			   공학설계 포스터발표경진대회 투표...   2013/12/10
# 			    2013년 졸업작품 브로셔    2013/10/07
# 			   제 4대 컴퓨터공학부 학회장/부학...   2012/11/05
# 			   디지털 시스템 설계1- [실습-조교]   2012/09/09
#
#
#
#
#
# 			   2015년 상반기 삼성 소프트웨어 ...   2014/09/25
# 			   과 잠바 불출공지입니다!!   2014/09/23
# 			   9/18 NHN Entertainment 캠퍼스 ...   2014/09/17
# 			   컴퓨터공학부 학술 소모임 씨앗(S...   2014/09/07
# 			   펜타시큐리티시스템 대학생 마케...   2014/09/05
#
#
#
#
#
# 			   세림티네스지(주) 인력 채용 공고   2014/09/30
# 			   (주)엠프론티어 시스템 운영/개발 ...   2014/09/15
# 			   컴퓨터공학부 학부사무실 청년인턴...   2014/08/06
# 			   (주)신진엠텍   2014/06/16
# 			   엑시콘  기술영업 채용. - 꼭 지도...   2014/04/18
#
#
#
#
#
#
#
#
#
#                      2014년 졸업...
#
#
#
#
#
#                      김재우처장...
#
#
#
#
#
#                      2014년 스승...
#
#
#
#
#
#
#
#
#
# 			   [특성화사업단]튜터링 프로그램 ...   2014/09/29
# 			   (공지)2014년 졸업작품 영어발표 ...   2014/09/25
# 			   [특성화사업단] IT경진대회 참가지원   2014/09/25
# 			   긴급] 졸업작품브로셔 검토   2014/09/25
# 			   레드햇 챌린지 안내   2014/09/23
# 			   [특성화사업단] 해외(일본) 기술...   2014/09/23
# 			   [특성화사업단]튜터링 모집공고(...   2014/09/22
#
#
#
#
#
# 			   [이슈분석] 문답으로 알아보는 단...   2014-09-30
# 			   [이슈분석] 휴대폰 판매점 사전승...   2014-09-30
# 			   [인사]미래창조과학부   2014-09-30
# 			   국내 진출 1년 맞는 보다폰, ‘M2M...   2014-09-30
# 			   재난망, LG CNS·SK C&amp;C와 KT 3파전   2014-09-30
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 총 단어의 수 = 188

# %% [markdown]
# ###**설명**
# - 문자열을 읽다가 '<'를 만나면 괄호 안에 있다는 의미로 is_in_par을 True로 바꿔준다. '>'를 만나기 전까지는 값을 저장하지 않는다.
# - `<style>`이나 `<script>`에서는 `</style>`이나 `</script>`를 만날 때까지 값을 저장하지 않아야하므로 is_style_script가 True일 때는 style문이나 script문 안에 있다는 의미로, 이 때는 값을 저장하지 않았다.
# - 한계 : 문서 내에 "< 작업 보고서 >" 같이, 태그가 아닌 내용도 제거된다.

# %% [markdown]
# -----
# ###**COMMENT**

# %% [markdown]
# - 파이썬 내에 다양하고 유용한 메소드가 많은데 잘 활용하지 못하고 있는 것 같다. 또 아직 익숙하지 않아서 조금만 복잡한 코드를 짜려고해도 문법이나 기능들이 너무 헷갈려서 많이 헤맸다.
# - 6번 문제를 구현하기가 가장 까다로웠다. 일반 HTML 태그와 STYLE, SCRIPT 태그를 구분해야했고, <!--`<BR>`--> 같은 코드처럼, <>내에 또다른 <>가 있을 경우, 이것을 제거하기위해 별도의 조치를 취해줘야만 했다. 막상 완성하고나니, 파이썬이 상당히 강력한 언어라는 것을 알 수 있었다. 이런 기능을 잘 이용하면 인터넷에 있는 수많은 데이터들을 가공해서 정보로 만드는데 용이할 것 같다.
# - 파이썬을 공부할수록 C/C++ 언어가 그리워진다. 파이썬같은 경우는 융통성은 있지만 일관성이 없는 탓에, 그리고 너무 많은 기능이 있는 탓에 더욱 어렵고 헷갈리게 느껴진다.
